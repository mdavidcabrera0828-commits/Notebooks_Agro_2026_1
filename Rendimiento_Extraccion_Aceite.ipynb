# %% [markdown]
# <a href="https://colab.research.google.com/github/mdavidcabrera0828-commits/Notebooks_Agro_2026_1/blob/main/Rendimiento_Extraccion_Aceite.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Control de Rendimiento en Extracción de Aceite**
#
#
# Este ejercicio es ideal para introducir float, int y la concatenación de strings.
#
# **Planteamiento:**
#
# Una planta procesadora de palma de aceite necesita calcular el **Índice de Rendimiento de Extracción (IRE)**. El operario debe ingresar el peso total de los racimos de fruta fresca (RFF) procesados en kilogramos y la cantidad de aceite crudo obtenido en litros.
#
#
# **Requerimientos:**
#
# 1. Solicitar el nombre del lote de producción (Tipo string).
# 2. Solicitar el peso de los racimos en kg (Tipo float). (pr)
# 3. Solicitar los litros de aceite obtenidos (Tipo float). (lt)
# 4. Calcular el rendimiento sabiendo que la densidad aproximada del aceite es de 0.92 kg/L. (r)
#
# $$pa = lt * 0.92$$
# $$r = (pa/pr)*100$$
#
#
# **Prueba del programa:**
#
# Si se ingresan 1000 kg de racimos y se obtienen 200 litros de aceite, el programa debe informar que el rendimiento del lote es del 18.4%.

# %%
# ENTRADA: Solicitar el nombre del lote de producción (Tipo string).
# Solicitar el peso de los racimos en kg (Tipo float). (pr)
# Solicitar los litros de aceite obtenidos (Tipo float). (lt)
nombre = input("Ingrese el nombre del lote: ")
pr = float(input("Ingrese el peso de los racimos en kg: "))
lt = float(input("Ingrese los litros de aceite obtenidos: "))

# PROCESOS: Calcular peso del aceote (pa) y el rendimiento (r)
pa = lt * 0.92
r = (pa/pr)*100

# SALIDA: Informar el rendimiento del lote
print("El rendimiento del lote", nombre, "es del", r, "%")
# Out:
# Ingrese el nombre del lote: El perico
# Ingrese el peso de los racimos en kg: 1000
# Ingrese los litros de aceite obtenidos: 200
# El rendimiento del lote El perico  es del 18.4 %

# %% [markdown]
# ```markdown
# ## Explicación del Código de Control de Rendimiento en Extracción de Aceite
#
# A continuación, se explica cada línea del código proporcionado:
#
# ```python
# # ENTRADA: Solicitar el nombre del lote de producción (Tipo string).
# # Solicitar el peso de los racimos en kg (Tipo float). (pr)
# # Solicitar los litros de aceite obtenidos (Tipo float). (lt)
# ```
# Estas líneas son comentarios que describen las secciones de "entrada" del programa. Indican que se solicitará el nombre del lote, el peso de los racimos en kilogramos (como un número decimal) y los litros de aceite obtenidos (también como un número decimal).
#
# ```python
# nombre = input("Ingrese el nombre del lote: ")
# ```
# Esta línea solicita al usuario que ingrese el nombre del lote de producción. El texto "Ingrese el nombre del lote: " se muestra en la consola, y lo que el usuario escribe se guarda como una cadena de texto en la variable `nombre`.
#
# ```python
# pr = float(input("Ingrese el peso de los racimos en kg: "))
# ```
# Esta línea pide al usuario que ingrese el peso de los racimos en kilogramos. El `input()` obtiene la entrada del usuario como una cadena, y `float()` convierte esa cadena a un número de coma flotante (decimal), que luego se guarda en la variable `pr`.
#
# ```python
# lt = float(input("Ingrese los litros de aceite obtenidos: "))
# ```
# Similar a la línea anterior, esta solicita los litros de aceite obtenidos. La entrada del usuario se convierte a un número de coma flotante y se almacena en la variable `lt`.
#
# ```python
# # PROCESOS: Calcular peso del aceote (pa) y el rendimiento (r)
# ```
# Este comentario introduce la sección donde se realizan los cálculos o "procesos" del programa, específicamente el peso del aceite (`pa`) y el rendimiento (`r`).
#
# ```python
# pa = lt * 0.92
# ```
# Esta línea calcula el peso del aceite (`pa`). Multiplica los litros de aceite (`lt`) por la densidad aproximada del aceite (0.92 kg/L). El resultado se guarda en la variable `pa`.
#
# ```python
# r = (pa/pr)*100
# ```
# Aquí se calcula el rendimiento de extracción (`r`). Se divide el peso del aceite (`pa`) por el peso de los racimos (`pr`), y el resultado se multiplica por 100 para obtener un porcentaje. El valor final se almacena en la variable `r`.
#
# ```python
# # SALIDA: Informar el rendimiento del lote
# ```
# Este comentario marca la sección de "salida", donde el programa presentará los resultados al usuario.
#
# ```python
# print("El rendimiento del lote", nombre, "es del", r, "%")
# ```
# Esta línea imprime el resultado final en la consola. Utiliza la función `print()` para mostrar una cadena de texto que incluye el nombre del lote (variable `nombre`), el rendimiento calculado (variable `r`) y el símbolo de porcentaje, concatenando todos estos elementos para formar una frase legible.
